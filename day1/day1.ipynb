# %%
print("Hello,world!")
# Out:
# Hello,world!

# %% [markdown]
# #### pandas (panel data sheet)----> data analyze
# #### plotly.express --------> data visualize

# %%
import pandas as pd
import plotly.express as pe

# %%
link = "https://raw.githubusercontent.com/techficent/PythonDABatch/main/TATASTEEL.NS.csv"

df = pd.read_csv(link)

df

# stock market! 1 share
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2013-01-21   39.538570   39.924427   39.205112   39.452824   14.199329
# 1     2013-01-22   39.452824   39.948246   38.790672   38.938347   14.014165
# 2     2013-01-23   39.100311   39.409950   38.357178   38.828781   13.974733
# 3     2013-01-24   38.928818   39.243221   38.371468   38.538197   13.870150
# 4     2013-01-25   38.557251   38.895473   37.971317   38.752563   13.947300
# ...          ...         ...         ...         ...         ...         ...
# 2464  2023-01-12  118.949997  119.250000  117.599998  118.099998  118.099998
# 2465  2023-01-13  118.550003  121.599998  118.150002  120.449997  120.449997
# 2466  2023-01-16  121.449997  121.449997  118.800003  119.949997  119.949997
# 2467  2023-01-17  119.750000  119.900002  118.000000  119.349998  119.349998
# 2468  2023-01-18  120.000000  123.000000  120.000000  122.449997  122.449997
#
#           Volume
# 0     26768709.0
# ...

# %% [markdown]
# ### On average: Tata steel share price (closing price): Average closing price

# %%
df.Close.mean()
# Out:
# 55.71950477462506

# %%
df.Close.max()
# Out:
# 151.940002

# %%
df.Close.min()
# Out:
# 18.888002

# %% [markdown]
# ### change in closing price

# %%
pe.line(      df,    x=df.Date,    y=df.Close    )
