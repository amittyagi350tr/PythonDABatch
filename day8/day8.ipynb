# %%
import pandas as pd
import plotly.express as pe

# %%
path = "/home/harshit/Desktop/PythonDA/datasets/Loan_Status_Classification.csv"
df = pd.read_csv(path)
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         0        1           1          0              0             6608
# 1         0        1           2          0              0             4226
# 2         1        1           0          1              0             3167
# 3         0        0           0          1              1             6950
# 4         0        1           0          1              0             3993
# ..      ...      ...         ...        ...            ...              ...
# 293       1        0           0          1              0             3846
# 294       0        0           0          1              0             2435
# 295       0        0           2          1              0             4923
# 296       0        1           3          0              0             2071
# 297       1        0           0          1              0             2378
#
# ...

# %% [markdown]
# ### data exploration

# %%
print(f"Shape of data is: {df.shape}")

print(f"Index of data is: {df.index}")

print(f"Columns are: {df.columns}")
# Out:
# Shape of data is: (298, 12)
# Index of data is: RangeIndex(start=0, stop=298, step=1)
# Columns are: Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             298 non-null    int64
#  1   Married            298 non-null    int64
#  2   Dependents         298 non-null    int64
#  3   Education          298 non-null    int64
#  4   Self_Employed      298 non-null    int64
#  5   ApplicantIncome    298 non-null    int64
#  6   CoapplicantIncome  298 non-null    int64
#  7   LoanAmount         298 non-null    int64
#  8   Loan_Amount_Term   298 non-null    int64
#  9   Credit_History     298 non-null    int64
#  10  Property_Area      298 non-null    int64
#  11  Loan_Status        298 non-null    int64
# dtypes: int64(12)
# memory usage: 28.1 KB

# %%
df.nunique()
# Out:
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      257
# CoapplicantIncome    150
# LoanAmount           145
# Loan_Amount_Term       9
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
df.isna().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.sample(3)
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 265       0        1           1          1              0             3315
# 58        0        1           3          0              1             7100
# 282       1        0           0          1              0            10000
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 265                  0          96               360               1
# 58                   0         125                60               1
# 282                  0         214               360               1
#
#      Property_Area  Loan_Status
# 265              2            1
# 58               1            1
# 282              2            0

# %%
real_value_columns = [ 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']

#categorical_columns is a list of an entry col repeated for every col in df.columns IF that col is not in real_value list
categorical_columns = [    col for col in df.columns if col not in real_value_columns    ]

# %%
df[   categorical_columns     ]   =   df[categorical_columns].astype('category')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298 entries, 0 to 297
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             298 non-null    category
#  1   Married            298 non-null    category
#  2   Dependents         298 non-null    category
#  3   Education          298 non-null    category
#  4   Self_Employed      298 non-null    category
#  5   ApplicantIncome    298 non-null    int64
#  6   CoapplicantIncome  298 non-null    int64
#  7   LoanAmount         298 non-null    int64
#  8   Loan_Amount_Term   298 non-null    category
#  9   Credit_History     298 non-null    category
#  10  Property_Area      298 non-null    category
#  11  Loan_Status        298 non-null    category
# dtypes: category(9), int64(3)
# memory usage: 11.1 KB

# %%
df[real_value_columns].describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount
# count       298.000000         298.000000  298.000000
# mean       5351.265101        1673.026846  143.560403
# std        6306.080712        2892.404818   80.395182
# min         150.000000           0.000000    9.000000
# 25%        2883.750000           0.000000   99.250000
# 50%        3854.000000        1106.000000  125.500000
# 75%        5721.500000        2281.000000  171.500000
# max       81000.000000       33837.000000  600.000000

# %%
df[categorical_columns].describe()
# Out:
#         Gender  Married  Dependents  Education  Self_Employed  \
# count      298      298         298        298            298
# unique       2        2           4          2              2
# top          0        1           0          1              0
# freq       245      187         176        235            258
#
#         Loan_Amount_Term  Credit_History  Property_Area  Loan_Status
# count                298             298            298          298
# unique                 9               2              3            2
# top                  360               1              2            1
# freq                 248             231            115          150

# %% [markdown]
# # Scatter Chart: a) Correlation between 2 numeric real-value columns
#
# # Box Chart: a) Outliers in the data or b) To check the quantiles(25th, 50th, 75th percentiles) in the data
#
# # Line Chart : a) To show trend(change in something) over a period of time(date & time)
#
# # Bar Chart : a) To show magnitude (value) of a set of categories(options)
#
# # Histogram : a) To count something!
#
# # strip chart a) to show correlation between real-value & categorical column
#
# # sunburst chart : a) to show proportion of categories in a categorical column with sub-division

# %% [markdown]
# ## Note:
# a) x axis
# b) y-axis
# c) data_frame
# d) colors
# e) Facet_row
# f) facet_col

# %% [markdown]
# ## box chart

# %%
pe.box(     y=real_value_columns,  data_frame=df        )

# %%
for col in real_value_columns:
    display(     pe.box(y=col, data_frame=df, color="Gender")                      )

# %% [markdown]
# min --->minimum value in the column
# max----> maximum value in the column
# median----> centre of the data that is 50th percentile point
# q1 ------> 25th percentile
# q3 -----> 75th percentile

# %% [markdown]
# 1) outliers:
#
#         a) IQR : Inter Quartile Range:  75th minus 25th percentile:   75
#         b) 1.5 times IQR = 112.50
#
#         outliers will data points that are EITHER
#                                 i) 112.5 units above 75th percentie OR  112.5 units below 25th percentile

# %% [markdown]
# #### count categories in all categorical column

# %%
for col in categorical_columns:
    display(    df[col].value_counts()    )
# Out:
# 0    245
# 1     53
# Name: Gender, dtype: int64
# 1    187
# 0    111
# Name: Married, dtype: int64
# 0    176
# 1     51
# 2     49
# 3     22
# Name: Dependents, dtype: int64
# 1    235
# 0     63
# Name: Education, dtype: int64
# 0    258
# 1     40
# Name: Self_Employed, dtype: int64
# 360    248
# 180     24
# 480     10
# 300      6
# 120      3
# 36       2
# 60       2
# 240      2
# 84       1
# Name: Loan_Amount_Term, dtype: int64
# 1    231
# 0     67
# Name: Credit_History, dtype: int64
# 2    115
# 1    106
# 3     77
# Name: Property_Area, dtype: int64
# 1    150
# 0    148
# Name: Loan_Status, dtype: int64

# %%
for col in categorical_columns:
    fig = pe.histogram(x=col, data_frame=df[col].astype('str'), color=col)
    display(      fig      )

# %%
data      bins
10        0-10

11        11-20


25        21-30


7         0-10


21        21-30



0-10:  2
11-20- 1
21-30: 2

# %%
for col in real_value_columns:
    fig = pe.histogram(x=col,data_frame=df, nbins=8, barmode='group')
    display(fig)

# %% [markdown]
# a) identify features/dimensions of data to be plotted
#     e.g: correlation between ApplicantIncome and LoanAmount
# b) evaluate what kind of graph is to be plotted
#     scatter chart
# c) arrangement/aesthetics

# %%
for col in categorical_columns:
    fig=pe.scatter(
            x="ApplicantIncome", 
            y="LoanAmount", 
            data_frame=df, 
            trendline='ols',
            color=col
        )
    
    display(fig)

# %% [markdown]
# ## Calculate the average LoanAmount for each category separately FOR each categorical column

# %%
# use a loop over all categorical columns
for col in categorical_columns:

    #average loan amount for categories in the current column
    data = df.groupby(   [col]   )[     ['LoanAmount']    ].mean()

    #rename of the column
    data = data.rename(    columns={"LoanAmount" : "AverageLoanAmount"}   )

    #create the figure: bar chart
    fig = pe.bar(data_frame=data,  x=data.index,   y='AverageLoanAmount', color=data.index)

    #fix the x axes so it looks like separate categories
    fig.update_xaxes(type='category')

    #display fig
    display(fig)

# %%
df.groupby(   ['Married']   ) [     ['LoanAmount']    ].mean()
# Out:
#          LoanAmount
# Married
# 0        129.648649
# 1        151.818182
