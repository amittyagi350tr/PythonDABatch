# %% [markdown]
# ### groupby operations

# %%
import pandas as pd
import plotly.express as pe

# %%
link = "https://raw.githubusercontent.com/techficent/PythonDABatch/main/titanic.csv"
df = pd.read_csv(link)
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# ### Average is called mean
# ### Total is called sum

# %% [markdown]
# aggregation : Mean, sum, min & max
# don't use all data together
#
# divide the data into sections and calculate aggregation separately
#
# sections must be categorical

# %% [markdown]
# ### step 1: select column/columns for groupby
# ### step 2: select the column with values for aggregation
# ### step 3: choose aggregation
#
# ### write the query now!

# %%
cols = [    "Pclass"    ]

values = [ "Age"  ]

operations = [ 'min', 'max' ]


df.groupby(      cols      )   [      values      ].agg(     operations      )
# Out:
#          Age
#          min   max
# Pclass
# 1       0.92  80.0
# 2       0.67  70.0
# 3       0.42  74.0

# %%
df.groupby(      [    "Pclass"    ]      )   [      [ "Age"  ]      ].agg(     [ 'min', 'max' ]      )
# Out:
#          Age
#          min   max
# Pclass
# 1       0.92  80.0
# 2       0.67  70.0
# 3       0.42  74.0

# %% [markdown]
# # Group by Pclass and Gender to find average Fare

# %%
cols = [ "Pclass", "Sex"  ]

values = ["Fare"]

operations = ["mean"]


df.groupby(   cols   ) [  values  ].agg( operations  )
# Out:
#                      Fare
#                      mean
# Pclass Sex
# 1      female  106.125798
#        male     67.226127
# 2      female   21.970121
#        male     19.741782
# 3      female   16.118810
#        male     12.661633

# %%
df.groupby(   [ "Pclass", "Sex"  ]   ) [  ["Fare"]  ].agg( ["mean"]  )
# Out:
#                      Fare
#                      mean
# Pclass Sex
# 1      female  106.125798
#        male     67.226127
# 2      female   21.970121
#        male     19.741782
# 3      female   16.118810
#        male     12.661633

# %% [markdown]
# ### How many data points are present in each group when grouping is according to Pclass?

# %%
df.groupby(    ['Pclass']    ).size()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %% [markdown]
# ## after grouping by Survived column, find few rows from each group (for sampling)

# %%
df.groupby(    ['Survived']     ).head(2)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 4      0            373450   8.0500   NaN        S

# %%
df.groupby(    ['Survived']     ).sample(2)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 42           42           43         0       3
# 439         439          440         0       2
# 299         299          300         1       1
# 437         437          438         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 42                               Kraeff, Mr. Theodor    male   NaN      0
# 439           Kvillner, Mr. Johan Henrik Johannesson    male  31.0      0
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 437            Richards, Mrs. Sidney (Emily Hocking)  female  24.0      2
#
#      Parch      Ticket      Fare    Cabin Embarked
# 42       0      349253    7.8958      NaN        C
# 439      0  C.A. 18723   10.5000      NaN        S
# 299      1    PC 17558  247.5208  B58 B60        C
# 437      3       29106   18.7500      NaN        S

# %% [markdown]
# ### find avergae, min & max of Age & Fare, for data grouped by Pclass, Gender, Survived & Embarked columns

# %%
cols = ["Pclass","Sex", "Survived", "Embarked"]

values = ["Age","Fare"]

operations = ["min","max", "mean"]

df.groupby(    cols    )[    values   ].agg(      operations     )
# Out:
#                                    Age                       Fare            \
#                                    min   max       mean       min       max
# Pclass Sex    Survived Embarked
# 1      female 0        C         50.00  50.0  50.000000   28.7125   28.7125
#                        S          2.00  25.0  13.500000  151.5500  151.5500
#               1        C         16.00  60.0  35.675676   27.7208  512.3292
#                        Q         33.00  33.0  33.000000   90.0000   90.0000
#                        S         14.00  63.0  33.619048   25.9292  263.0000
#        male   0        C         18.00  71.0  43.050000   27.7208  247.5208
#                        Q         44.00  44.0  44.000000   90.0000   90.0000
#                        S         19.00  70.0  45.362500    0.0000  263.0000
#               1        C         17.00  60.0  36.437500   26.5500  512.3292
#                        S          0.92  80.0  36.121667   26.2875  151.5500
# ...

# %% [markdown]
# ### conditions:
#
# for e.g:  find data for passengers with over 20 years age!
#         find data for passengers who paid fare between 100-200 AND are female passengers
#
#
# ### steps
#             a) condition should be defined
#             b) apply the condition

# %%
condition1 = (    df.Age   >   20    ) #writing condition

df.loc[      condition1         ] #location rows with matching condition
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 884         884          885         0       3
# 885         885          886         0       3
# 886         886          887         0       2
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# ## find Name & Age for passengers who paid fare between 100-200 AND are female passengers

# %%
condition1=(   df.Sex == "female"     )

condition2 = (    df.Fare.between(100,200)           )


df.loc[      condition1  &   condition2 ,     ['Name', "Age"]             ]
# Out:
#                                                   Name   Age
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)   NaN
# 195                               Lurette, Miss. Elise  58.0
# 215                            Newell, Miss. Madeleine  31.0
# 268      Graham, Mrs. William Thompson (Edith Junkins)  58.0
# 269                             Bissette, Miss. Amelia  35.0
# 297                       Allison, Miss. Helen Loraine   2.0
# 306                            Fleming, Miss. Margaret   NaN
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  17.0
# 318                           Wick, Miss. Mary Natalie  31.0
# 319  Spedden, Mrs. Frederic Oakley (Margaretta Corn...  40.0
# 325                           Young, Miss. Marie Grice  36.0
# 334  Frauenthal, Mrs. Henry William (Clara Heinshei...   NaN
# 337                    Burns, Miss. Elizabeth Margaret  41.0
# 393                             Newell, Miss. Marjorie  23.0
# ...

# %% [markdown]
# ### Names of passengers who are travelling in Pclass 1 OR people who paid over 200 Fare

# %%
condition1=(df.Pclass == 1)
condition2=(df.Fare > 200)

df[condition1   |   condition2  ]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 1             1            2         1       1
# 3             3            4         1       1
# 6             6            7         0       1
# 11           11           12         1       1
# 23           23           24         1       1
# ..          ...          ...       ...     ...
# 871         871          872         1       1
# 872         872          873         0       1
# 879         879          880         1       1
# 887         887          888         1       1
# 889         889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %%
5 rows of data

Id, Name, Age
1   Harshit  32
2   Pranali  24
3   Rupa     30
4   Rohan    29
5   Ajay     45

# %%
data = {
    "Id" :  [1,2,3,4,5],

    "Name"  : ["Harshit", "Pranali", "Rupa", "Rohan", "Ajay"],

    "Age" : [32, 24, 30, 29, 45],

}


temp=pd.DataFrame(     data    )

temp
# Out:
#    Id     Name  Age
# 0   1  Harshit   32
# 1   2  Pranali   24
# 2   3     Rupa   30
# 3   4    Rohan   29
# 4   5     Ajay   45
